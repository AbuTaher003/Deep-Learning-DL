# %%
import numpy as np

docs = [
    'go Bangladesh', 
    'Bangladesh Bangladesh',
    'I love Bangladesh',
    'Inquilab Zindabad',
    'go go go',
    'Messi is the best',
    'I love football',
    'football is life',
    'Inquilab is the movement',
    'Que miras bobo'
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'go': 1,
#  'bangladesh': 2,
#  'is': 3,
#  'i': 4,
#  'love': 5,
#  'inquilab': 6,
#  'the': 7,
#  'football': 8,
#  'zindabad': 9,
#  'messi': 10,
#  'best': 11,
#  'life': 12,
#  'movement': 13,
#  'que': 14,
#  'miras': 15,
#  'bobo': 16}

# %%
tokenizer.word_index
# Out:
# {'go': 1,
#  'bangladesh': 2,
#  'is': 3,
#  'i': 4,
#  'love': 5,
#  'inquilab': 6,
#  'the': 7,
#  'football': 8,
#  'zindabad': 9,
#  'messi': 10,
#  'best': 11,
#  'life': 12,
#  'movement': 13,
#  'que': 14,
#  'miras': 15,
#  'bobo': 16}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 4),
#              ('bangladesh', 4),
#              ('i', 2),
#              ('love', 2),
#              ('inquilab', 2),
#              ('zindabad', 1),
#              ('messi', 1),
#              ('is', 3),
#              ('the', 2),
#              ('best', 1),
#              ('football', 2),
#              ('life', 1),
#              ('movement', 1),
#              ('que', 1),
#              ('miras', 1),
#              ('bobo', 1)])

# %%
tokenizer.document_count
# Out:
# 10

# %%
sequences = tokenizer.texts_to_sequences(docs)

# %%
sequences
# Out:
# [[1, 2],
#  [2, 2],
#  [4, 5, 2],
#  [6, 9],
#  [1, 1, 1],
#  [10, 3, 7, 11],
#  [4, 5, 8],
#  [8, 3, 12],
#  [6, 3, 7, 13],
#  [14, 15, 16]]

# %%
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences, padding = 'post' )

# %%
sequences
# Out:
# array([[ 1,  2,  0,  0],
#        [ 2,  2,  0,  0],
#        [ 4,  5,  2,  0],
#        [ 6,  9,  0,  0],
#        [ 1,  1,  1,  0],
#        [10,  3,  7, 11],
#        [ 4,  5,  8,  0],
#        [ 8,  3, 12,  0],
#        [ 6,  3,  7, 13],
#        [14, 15, 16,  0]], dtype=int32)

# %%
import tensorflow

from tensorflow import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import *

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data()

# %%
X_train[0]
# Out:
# [1,
#  14,
#  22,
#  16,
#  43,
#  530,
#  973,
#  1622,
#  1385,
#  65,
#  458,
#  4468,
#  66,
#  3941,
#  4,
#  173,
#  36,
#  256,
#  5,
#  25,
#  100,
#  43,
#  838,
#  112,
#  50,
#  670,
#  22665,
#  9,
#  35,
#  480,
#  284,
#  5,
#  150,
#  4,
#  172,
#  112,
#  167,
#  21631,
#  336,
#  385,
#  39,
#  4,
#  172,
#  4536,
#  1111,
#  17,
#  546,
#  38,
#  13,
#  447,
#  4,
#  192,
#  50,
#  16,
#  6,
#  147,
#  2025,
#  19,
#  14,
#  22,
#  4,
#  1920,
#  4613,
#  469,
#  4,
#  22,
#  71,
#  87,
#  12,
#  16,
#  43,
#  530,
#  38,
#  76,
#  15,
#  13,
#  1247,
#  4,
#  22,
#  17,
#  515,
#  17,
#  12,
#  16,
#  626,
#  18,
#  19193,
#  5,
#  62,
#  386,
#  12,
#  8,
#  316,
#  8,
#  106,
#  5,
#  4,
#  2223,
#  5244,
#  16,
#  480,
#  66,
#  3785,
#  33,
#  4,
#  130,
#  12,
#  16,
#  38,
#  619,
#  5,
#  25,
#  124,
#  51,
#  36,
#  135,
#  48,
#  25,
#  1415,
#  33,
#  6,
#  22,
#  12,
#  215,
#  28,
#  77,
#  52,
#  5,
#  14,
#  407,
#  16,
#  82,
#  10311,
#  8,
#  4,
# ...

# %%
len(X_train[1]) # is it columns or rows? --> rows
# Out:
# 189

# %%
X_train = pad_sequences(X_train, padding = 'post', maxlen = 50)
X_test = pad_sequences(X_test, padding = 'post', maxlen = 50)

# %%
X_train[0]
# Out:
# array([2071,   56,   26,  141,    6,  194, 7486,   18,    4,  226,   22,
#          21,  134,  476,   26,  480,    5,  144,   30, 5535,   18,   51,
#          36,   28,  224,   92,   25,  104,    4,  226,   65,   16,   38,
#        1334,   88,   12,   16,  283,    5,   16, 4472,  113,  103,   32,
#          15,   16, 5345,   19,  178,   32], dtype=int32)

# %%
model = Sequential()

model.add(SimpleRNN(32, input_shape = (50, 1), return_sequences = False)) # Ekhane (50, 1)er mane hocche, 50 time steps and 1 mane holo feature dimension 1.
model.add(Dense(1, activation = 'sigmoid'))

model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
model.fit(X_train, y_train, epochs = 5, validation_data = (X_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5077 - loss: 0.6967 - val_accuracy: 0.5029 - val_loss: 0.6942
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5066 - loss: 0.6933 - val_accuracy: 0.5020 - val_loss: 0.6949
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5055 - loss: 0.6932 - val_accuracy: 0.5082 - val_loss: 0.6941
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5100 - loss: 0.6917 - val_accuracy: 0.5080 - val_loss: 0.6950
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5014 - loss: 0.6933 - val_accuracy: 0.5045 - val_loss: 0.6952
